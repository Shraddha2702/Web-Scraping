# %%
from bs4 import BeautifulSoup
import requests

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',100)

# %%
#Very First Try

# %%
url = 'https://www.myntra.com/men-tshirts'

# %%
html_doc = requests.get(url)

# %%
html_doc
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(html_doc.text, 'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <title>\n   Men T-shirts - Buy T-shirts for Men Online in India - Myntra\n  </title>\n  <meta content="#fffff" name="theme-color"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <link href="https://www.myntra.com/amp/men-tshirts" rel="amphtml"/>\n  <link href="data:image/x-icon;base64,..." rel="icon" type="image/x-icon">\n   <link href="https://cdn.myntassets.com" rel="dns-prefetch">\n    <link href="https://assets.myntassets.com" rel="dns-prefetch"/>\n    <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>\n    <link href="https://www.google-analytics.com" rel="dns-prefetch"/>\n    <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>\n    <meta content="787245060481-4padi0c9g2l1pnbie52fmpfdpo43209i.apps.googleusercontent.com" name="google-signin-client_id"/>\n    <meta content="single_host_origin" name="google-signin-cookiepolicy"/>\n    <meta content="profile email" name="google-
# ...

# %%
soup.find_all('a')
# Out:
# [<a class="myntraweb-sprite desktop-logo sprites-logo" data-reactid="6" href="/"></a>,
#  <a class="desktop-main" data-color="#ee5f73" data-group="men" data-index="0" data-reactid="11" data-type="navElements" href="/shop/men" style="border-bottom-color:#ee5f73;">Men</a>,
#  <a class="desktop-categoryName" data-reactid="16" href="/men-topwear?src=tNav" style="color:#ee5f73;">Topwear</a>,
#  <a class="desktop-categoryLink" data-reactid="18" href="/men-tshirts?src=tNav" style="color:;">T-Shirts</a>,
#  <a class="desktop-categoryLink" data-reactid="20" href="/men-casual-shirts?src=tNav" style="color:;">Casual Shirts</a>,
#  <a class="desktop-categoryLink" data-reactid="22" href="/men-formal-shirts?src=tNav" style="color:;">Formal Shirts</a>,
#  <a class="desktop-categoryLink" data-reactid="24" href="/men-sweatshirts?src=tNav" style="color:;">Sweaters &amp; Sweatshirts</a>,
#  <a class="desktop-categoryLink" data-reactid="26" href="/men-jackets?src=tNav" style="color:;">Jackets</a>,
# ...

# %%
#Second Try

# %%
call = requests.get('https://cdn.myntassets.com/web/assets/css/main.a29732dd5d3954ad3515.css.gz')

# %%
call2 = requests.get('https://assets.myntassets.com/dpr_3/h_240,q_90,w_180/v1/assets/images/')

# %%
type(call2)
# Out:
# requests.models.Response

# %%
call2.headers['content-type']
# Out:
# 'image/gif'

# %%
call2.encoding

# %%
call2.headers
# Out:
# {'X-UA-Compatible': 'IE=Edge,chrome=1', 'Timing-Allow-Origin': '*', 'Status': '400 Bad Request', 'Connection': 'keep-alive', 'Access-Control-Allow-Origin': '*', 'Date': 'Wed, 04 Apr 2018 12:43:18 GMT', 'Expires': 'Wed, 04 Apr 2018 13:12:37 GMT', 'Cache-Control': 'private, max-age=1759', 'X-Request-Id': '28f428dc677c7dc8', 'Content-Length': '0', 'Server': 'cloudinary', 'Content-Disposition': 'inline', 'Access-Control-Allow-Headers': 'X-Requested-With', 'Content-Transfer-Encoding': 'binary', 'Content-Type': 'image/gif', 'Access-Control-Expose-Headers': 'X-Cld-Error', 'X-Cld-Error': 'public_id (assets/images/) is invalid'}

# %%
#Trying the Iframe technique to retrieve Images.. Still Failed !

# %%
soup.find_all('iframe')
# Out:
# [<iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-H34B" style="display:none;visibility:hidden" width="0"></iframe>]

# %%
import urllib
urllib.urlretrieve("http://photogallery.sandesh.com/Picture.aspx?AlubumId=422040", "Abc.jpg")

# %%
#URLLib Finally Worked, Got the image url from the 'Networks' Tab, used it to retrieve the single Image

# %%
import urllib.request

# %%
urllib.request.urlretrieve('https://assets.myntassets.com/dpr_3/h_240,q_90,w_180/v1/assets/images/1554405/2016/10/26/11477468421149-Duke-Men-Tshirts-7261477468420959-1_mini.jpg', '1.jpg')
# Out:
# ('1.jpg', <http.client.HTTPMessage at 0x7fb9306b1b00>)

# %%
#Now the Mission was to retrieve all such images

# %%
call2.headers['content-type']
# Out:
# 'image/gif'

# %%
htmlp = requests.get('https://assets.myntassets.com/dpr_3/h_240,q_90,w_180/v1/assets/images/')
latest = BeautifulSoup(htmlp.text, 'html.parser')

# %%
import re

# %%
#Had a hard time trying to find the location of images and how retrieval can be done.. Tried regex !

# %%
re.findall('https://assets.myntassets.com/dpr_3/h_240,q_90,w_180/v1/assets/images/+')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-1e2641ae3ca4> in <module>()
# ----> 1 re.findall('https://assets.myntassets.com/dpr_3/h_240,q_90,w_180/v1/assets/images/+')
#
# TypeError: findall() missing 1 required positional argument: 'string'

# %%
source_url = 'https://assets.myntassets.com/dpr_3/h_240,q_90,w_180/v1/assets/images/'

r = requests.get(source_url, stream=True)
if r.status_code == 200:
    with open(sink_path, 'wb') as f:
        print('Inside')
        for chunk in r:
            f.write(chunk)

# %%
1554405/2016/10/26/11477468421149-Duke-Men-Tshirts-7261477468420959-1_mini.jpg

# %%
source_reg = 'https://assets.myntassets.com/dpr_3/h_240,q_90,w_180/v1/assets/images/([0-9]+/[0-9]+/[0-9]+/[0-9]+/[0-9]+)-([a-zA-Z]+)-([A-Za-z]+)-([A-Za-z]+)-([0-9]+)-([0-9]+)_([a-z]+).jpg'
def getImageLocation():
  with urllib2.urlopen('https://assets.myntassets.com/dpr_3/h_240,q_90,w_180/v1/assets/images/') as h:
    # (?<=...) means "Matches if the current position in the string 
    #                 is preceded by a match for ... 
    #                 that ends at the current position."
    loc = re.search(source_reg, a).group()
    print('https://assets.myntassets.com/dpr_3/h_240,q_90,w_180/v1/assets/images/' + loc)
  return 'https://assets.myntassets.com/dpr_3/h_240,q_90,w_180/v1/assets/images/' + loc

# %%
#Finally Retrieved single Image

# %%
s1 = 'https://assets.myntassets.com/'
req = requests.get(s1)

# %%
req.headers
# Out:
# {'X-UA-Compatible': 'IE=Edge,chrome=1', 'Timing-Allow-Origin': '*', 'Status': '400 Bad Request', 'Connection': 'keep-alive', 'Pragma': 'no-cache', 'Access-Control-Allow-Origin': '*', 'Date': 'Wed, 04 Apr 2018 13:16:12 GMT', 'Expires': 'Wed, 04 Apr 2018 13:16:12 GMT', 'Cache-Control': 'no-cache, no-store', 'X-Request-Id': '01ff12d29f0c3d60', 'Content-Length': '0', 'Server': 'cloudinary', 'Content-Disposition': 'inline', 'Access-Control-Allow-Headers': 'X-Requested-With', 'Content-Transfer-Encoding': 'binary', 'Content-Type': 'image/gif', 'Access-Control-Expose-Headers': 'X-Cld-Error', 'X-Cld-Error': 'public_id (upload/) is invalid'}

# %%
url = 'https://www.myntra.com/men-tshirts'
html = requests.get(url)
soup = BeautifulSoup(html.text, 'html.parser')

# %%
a = soup.find('div',id='mountRoot')

# %%
a.find('main', 'search-base')

# %%
import json

# %%
b = soup.find_all('script',type="application/ld+json")[1]

# %%
b
# Out:
# <script type="application/ld+json"> {"@context":"https://schema.org","@type":"Product","name":"ETHER Grey Melange Henley T-shirt","image":"http://myntra.myntassets.com/assets/images/1032028/2015/11/26/11448535065590-ETHER-Grey-Melange-Henley-T-shirt-7761448535065172-1.jpg","brand":{"@type":"Thing","name":"ether"}}</script>

# %%
im = json.loads(b.text)['image']

# %%
urllib.request.urlretrieve(im,'1.jpg')
# Out:
# ('1.jpg', <http.client.HTTPMessage at 0x7fb92ed78be0>)

# %%
#Common Script to retrieve all images

# %%
req = soup.find_all('script', type="application/ld+json")
i = 0
for elem in req:
    if 'image' in json.loads(elem.text):
        urllib.request.urlretrieve(json.loads(elem.text)['image'],str(i)+'.jpg')
        i = i + 1

# %%
#Now let's try to get all the other images !

# %%
try2 = 'https://assets.myntassets.com'
htm = requests.get(try2)
soup2 = BeautifulSoup(htm.text, 'html.parser')

# %%
print(soup.header.prettify())
# Out:
# <header class="desktop-container" data-reactid="3" id="desktop-header-cnt">
#  <div class="desktop-bound" data-reactid="4">
#   <div class="desktop-logoContainer" data-reactid="5">
#    <a class="myntraweb-sprite desktop-logo sprites-logo" data-reactid="6" href="/">
#    </a>
#   </div>
#   <nav class="desktop-navbar" data-reactid="7">
#    <div class="desktop-navLinks" data-reactid="8">
#     <div class="desktop-navContent" data-reactid="9">
#      <div class="desktop-navLink" data-reactid="10">
#       <a class="desktop-main" data-color="#ee5f73" data-group="men" data-index="0" data-reactid="11" data-type="navElements" href="/shop/men" style="border-bottom-color:#ee5f73;">
#        Men
#       </a>
#       <div class="desktop-paneContent" data-reactid="12">
#        <div class="desktop-categoryContainer" data-color="#ee5f73" data-group="men" data-index="0" data-reactid="13">
#         <ul class="desktop-navBlock" data-reactid="14">
#          <li data-reactid="15">
# ...
